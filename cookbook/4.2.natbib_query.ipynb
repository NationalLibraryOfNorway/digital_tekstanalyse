# %% [markdown]
# # Søk Nasjonalbibliografiens metadata med dhlab

# %%
from dhlab.metadata.natbib import metadata_query, metadata_from_urn, pretty_print_marc21json

# %%
q = [
        ["245", "a", "kongen"]
        ]

metadata_query(q, limit = 3)
# Out:
# ['URN:NBN:no-nb_digibok_2011011206017',
#  'URN:NBN:no-nb_digibok_2013022006043',
#  'URN:NBN:no-nb_digibok_2007080901030']

# %% [markdown]
# `metadata_query` tar en liste med tupler, der hver tuppel en MARC 21 delfelt

# %%
urns = metadata_query(
    [
        ("100", "a", "Ibsen")
        ],
    limit=2
                    )
urns
# Out:
# ['URN:NBN:no-nb_digibok_2010021813003', 'URN:NBN:no-nb_digibok_2009042804050']

# %% [markdown]
# `metadata_from_urn` tar en liste med URNer, og returnerer MARC 21 metadata i json-format

# %%
metadata = metadata_from_urn(urns, fields=["245", "100", "008"])
metadata
# Out:
# [{'fields': [{'001': '999431354864702202'},
#    {'005': '20211030193533.0'},
#    {'007': 'ta'},
#    {'007': 'cr||||||||||||'},
#    {'008': '101210s1898    xx#||||| |||||000|u|ger|d'},
#    {'035': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '943135486-47bibsys_network'}]}},
#    {'035': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '(NO-TrBIB)943135486'}]}},
#    {'035': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '(NO-TrBIB)100679161'}]}},
#    {'035': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '(EXLNZ-47BIBSYS_NETWORK)999431354864702201'}]}},
#    {'040': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'NO-TrBIB'}, {'b': 'nob'}, {'e': 'katreg'}]}},
#    {'092': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '839.822[S]'}, {'q': 'NO-OsNB'}, {'9': 'LOCAL'}]}},
#    {'100': {'ind1': '1',
#      'ind2': ' ',
#      'subfields': [{'a': 'Ibsen, Henrik'},
#       {'d': '1828-1906'},
#       {'0': '(NO-TrBIB)90061718'}]}},
#    {'245': {'ind1': '1',
#      'ind2': ' ',
#      'subfields': [{'a': 'Henrik Ibsens sämtliche Werke in deutscher Sprache'},
#       {'n': '3'}]}},
#    {'260': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'Berlin'}, {'b': 'Fischer'}, {'c': '[1898?]'}]}},
#    {'300': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a': 'XXXI, 350 s.'}]}},
#    {'505': {'ind1': '0',
#      'ind2': ' ',
#      'subfields': [{'a': 'Die Helden auf Helgeland (Nordische Heerfahrt) ; Komödie der Liebe ; Die Kronprätendenten'}]}},
#    {'533': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'Elektronisk reproduksjon'},
#       {'b': '[Norge]'},
#       {'c': 'Nasjonalbiblioteket Digital'},
#       {'d': '2010-03-22'}]}},
#    {'600': {'ind1': '1',
#      'ind2': '7',
#      'subfields': [{'a': 'Ibsen, Henrik'},
#       {'d': '1828-1906'},
#       {'0': '(NO-TrBIB)90061718'},
#       {'2': 'bare'}]}},
#    {'700': {'ind1': '1',
#      'ind2': ' ',
#      'subfields': [{'a': 'Brandes, Georg'},
#       {'d': '1842-1927'},
#       {'0': '(NO-TrBIB)90051153'}]}},
#    {'700': {'ind1': '1',
#      'ind2': ' ',
#      'subfields': [{'a': 'Elias, Julius,'},
#       {'d': '1861-1927'},
#       {'0': '(NO-TrBIB)90713803'}]}},
#    {'700': {'ind1': '1',
#      'ind2': ' ',
#      'subfields': [{'a': 'Schlenther, Paul,'},
#       {'d': '1854-1916'},
#       {'0': '(NO-TrBIB)90753256'}]}},
#    {'740': {'ind1': '0',
#      'ind2': ' ',
#      'subfields': [{'a': 'Sämtliche Werke in deutscher sprache'}]}},
#    {'773': {'ind1': '0',
#      'ind2': '8',
#      'subfields': [{'i': 'Inkludert i'},
#       {'a': 'Ibsen, Henrik, 1828-1906'},
#       {'s': 'Verker. Tysk'},
#       {'t': 'Henrik Ibsens sämtliche Werke in deutscher Sprache'},
#       {'d': 'Berlin : Fischer, 1898-1904'},
#       {'g': '3'},
#       {'w': '999431353894702201'}]}},
#    {'856': {'ind1': '4',
#      'ind2': '1',
#      'subfields': [{'3': 'Fulltekst'},
#       {'u': 'https://www.nb.no/search?q=oaiid:"oai:nb.bibsys.no:999431354864702202"&mediatype=bøker'},
#       {'y': 'Nettbiblioteket'},
#       {'z': 'Søke-URL'}]}},
#    {'901': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a': '80'}]}},
#    {'913': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'Ibsensamlingen'}, {'b': 'NB'}]}},
#    {'787': {'ind1': '0',
#      'ind2': ' ',
#      'subfields': [{'t': 'NB Digital '},
#       {'w': '81209487210002202'},
#       {'i': 'Alma Collection'}]}},
#    {'AVD': {'ind1': '1',
#      'ind2': ' ',
#      'subfields': [{'0': '32210263250002202'},
#       {'b': '0183306'},
#       {'c': 'NB Digital'},
#       {'u': 'http://urn.nb.no/URN:NBN:no-nb_digibok_2010021813003'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: mini - mini'},
#       {'p': '74ga02129'},
#       {'q': '74ga02129'},
#       {'c': 'g00005'},
#       {'z': '(Til bruk på NB Oslos lesesal)'},
#       {'0': '23199165690002202'},
#       {'b': '0030100'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: mini - mini'},
#       {'p': '85ga50964'},
#       {'q': '85ga50964'},
#       {'c': 'g00005'},
#       {'z': '(ib.)'},
#       {'0': '23199165540002202'},
#       {'b': '0030100'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: mini - mini'},
#       {'p': '85ga06591'},
#       {'q': '85ga06591'},
#       {'c': 'g00005'},
#       {'z': '(Proveniens: Ibsenarvingene)(Oppstilt i Ibsenmuseet)'},
#       {'0': '23199165640002202'},
#       {'b': '0030100'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: mini - mini'},
#       {'p': '85ga06590'},
#       {'q': '85ga06590'},
#       {'c': 'g00005'},
#       {'z': '(Proveniens: Ibsenarvingene)(Oppstilt i Ibsenmuseet)'},
#       {'0': '23199165670002202'},
#       {'b': '0030100'}]}}],
#   'leader': '01415cam a2200313 c 4500',
#   'mmsid': {'nb': '999431354864702202', 'sikt': '999431354864702201'},
#   'urn': 'URN:NBN:no-nb_digibok_2010021813003',
#   'urn_link': 'http://urn.nb.no/URN:NBN:no-nb_digibok_2010021813003'},
#  {'fields': [{'001': '999900472104702202'},
#    {'005': '20221018124635.0'},
#    {'007': 'ta'},
#    {'007': 'cr||||||||||||'},
#    {'008': '131104s1998    no#||||| |||||000|0|nob| '},
#    {'015': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '9906187'}, {'2': 'nbf'}]}},
#    {'020': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '8251836832'}, {'q': 'ib.'}, {'c': 'Nkr 198.00'}]}},
#    {'035': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '990047210-47bibsys_network'}]}},
#    {'035': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '(NO-TrBIB)990047210'}]}},
#    {'035': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '(NO-TrBIB)092464866'}]}},
#    {'035': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '(EXLNZ-47BIBSYS_NETWORK)999900472104702201'}]}},
#    {'040': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'NO-OsNB'}, {'b': 'nob'}, {'e': 'katreg'}]}},
#    {'042': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a': 'norbibl'}]}},
#    {'044': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'c': 'no'}]}},
#    {'080': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a': '663.91(481)'}]}},
#    {'080': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a': '061.5(481)'}]}},
#    {'080': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a': '663.91(047.3)'}]}},
#    {'080': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '92 Throne-Holst, Johan'}]}},
#    {'080': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a': '(047.3)'}]}},
#    {'080': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '663'}, {'2': 'UDC Medium edition'}]}},
#    {'082': {'ind1': '7',
#      'ind2': '4',
#      'subfields': [{'a': '338.76641'}, {'q': 'NO-OsNB'}, {'2': '4/nor'}]}},
#    {'084': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'Nb 32(Jc 10)'}, {'2': 'ubtkl/2'}]}},
#    {'084': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'Cc'}, {'2': 'knt'}]}},
#    {'100': {'ind1': '1',
#      'ind2': ' ',
#      'subfields': [{'a': 'Ibsen, Hilde'}, {'d': '1961-'}]}},
#    {'245': {'ind1': '1',
#      'ind2': '3',
#      'subfields': [{'a': 'Et lite stykke Norge :'},
#       {'b': 'Freia 100 år'},
#       {'c': 'Hilde Ibsen'}]}},
#    {'260': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '[Oslo]'}, {'b': 'Tano Aschehoug'}, {'c': 'c1998'}]}},
#    {'300': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': '168 s.'}, {'b': 'ill.'}]}},
#    {'500': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'Omhandler bl.a. Johan Throne Holst og etterkommere'}]}},
#    {'533': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'Elektronisk reproduksjon'},
#       {'b': '[Norge]'},
#       {'c': 'Nasjonalbiblioteket Digital'},
#       {'d': '2009-05-17'}]}},
#    {'600': {'ind1': '1',
#      'ind2': '7',
#      'subfields': [{'a': 'Throne-Holst'},
#       {'c': 'slekten'},
#       {'0': '(NO-TrBIB)99023016'},
#       {'2': 'bare'}]}},
#    {'600': {'ind1': '3',
#      'ind2': '4',
#      'subfields': [{'a': 'Throne-Holst'}, {'c': 'slekten'}]}},
#    {'610': {'ind1': '2',
#      'ind2': '7',
#      'subfields': [{'a': 'Freia, A/S'},
#       {'0': '(NO-TrBIB)90249112'},
#       {'2': 'bare'}]}},
#    {'653': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'industri'},
#       {'a': 'oslo'},
#       {'a': 'sukkervarer'},
#       {'a': 'sjokolade'},
#       {'a': 'industrihistorie'},
#       {'a': 'næringsmiddelindustri'}]}},
#    {'651': {'ind1': ' ',
#      'ind2': '7',
#      'subfields': [{'a': 'Norge'},
#       {'2': 'humord'},
#       {'0': '(NO-TrBIB)HUME02605'}]}},
#    {'650': {'ind1': ' ',
#      'ind2': '7',
#      'subfields': [{'a': 'Historisk framstilling'},
#       {'2': 'humord'},
#       {'0': '(NO-TrBIB)HUME04097'}]}},
#    {'650': {'ind1': ' ',
#      'ind2': '7',
#      'subfields': [{'a': 'Næringsmidler'},
#       {'2': 'humord'},
#       {'0': '(NO-TrBIB)HUME12039'}]}},
#    {'650': {'ind1': ' ',
#      'ind2': '7',
#      'subfields': [{'a': 'Industri'},
#       {'2': 'humord'},
#       {'0': '(NO-TrBIB)HUME07682'}]}},
#    {'650': {'ind1': ' ',
#      'ind2': '7',
#      'subfields': [{'a': 'Nytelsesmidler'},
#       {'2': 'humord'},
#       {'0': '(NO-TrBIB)HUME12042'}]}},
#    {'856': {'ind1': '4',
#      'ind2': '2',
#      'subfields': [{'3': 'Forlagets beskrivelse (kort)'},
#       {'u': 'https://contents.bibs.aws.unit.no/?isbn=8251836832'}]}},
#    {'856': {'ind1': '4',
#      'ind2': '1',
#      'subfields': [{'3': 'Fulltekst'},
#       {'u': 'https://www.nb.no/search?q=oaiid:"oai:nb.bibsys.no:999900472104702202"&mediatype=bøker'},
#       {'y': 'Nettbiblioteket'},
#       {'z': 'Søke-URL'}]}},
#    {'901': {'ind1': ' ', 'ind2': ' ', 'subfields': [{'a': '90'}]}},
#    {'913': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'a': 'Norbok'}, {'b': 'NB'}]}},
#    {'787': {'ind1': '0',
#      'ind2': ' ',
#      'subfields': [{'t': 'NB Digital '},
#       {'w': '81209487210002202'},
#       {'i': 'Alma Collection'}]}},
#    {'AVD': {'ind1': '1',
#      'ind2': ' ',
#      'subfields': [{'0': '32215186560002202'},
#       {'b': '0183306'},
#       {'s': '99sd06752'},
#       {'c': 'NB Digital'},
#       {'u': 'http://urn.nb.no/URN:NBN:no-nb_digibok_2009042804050'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: kat - kat'},
#       {'p': '99ga03570'},
#       {'q': '99ga03570'},
#       {'c': 'g00005'},
#       {'z': '(ib.) (Til bruk på NB Oslos lesesal)'},
#       {'0': '23153118760002202'},
#       {'b': '0030100'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: kat - kat'},
#       {'p': '99sa00538'},
#       {'q': '99sa00538'},
#       {'c': 'g00001'},
#       {'0': '23153118800002202'},
#       {'b': '0183334'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: kat - kat | NON PUBLIC NOTE: HHo  99'},
#       {'p': '99ga17177'},
#       {'q': '99ga17177'},
#       {'c': 'g00005'},
#       {'z': '(ib.) (TAPT 20-2-2002)'},
#       {'0': '23153118720002202'},
#       {'b': '0030100'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: mini - mini'},
#       {'p': '75sd64557'},
#       {'q': '75sd64557'},
#       {'c': 'g00030'},
#       {'0': '23153118650002202'},
#       {'b': '0183300'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: kat - kat'},
#       {'p': '99sd25752'},
#       {'q': '99sd25752'},
#       {'c': 'g00030'},
#       {'0': '23153118680002202'},
#       {'b': '0183300'}]}},
#    {'AVP': {'ind1': ' ',
#      'ind2': ' ',
#      'subfields': [{'x': 'Status: mini - mini'},
#       {'p': '75sd64556'},
#       {'q': '75sd64556'},
#       {'c': 'g00030'},
#       {'0': '23153118660002202'},
#       {'b': '0183300'}]}}],
#   'leader': '01908cam a2200517 c 4500',
#   'mmsid': {'nb': '999900472104702202', 'sikt': '999900472104702201'},
#   'urn': 'URN:NBN:no-nb_digibok_2009042804050',
#   'urn_link': 'http://urn.nb.no/URN:NBN:no-nb_digibok_2009042804050'}]

# %%
for x in metadata:
    pretty_print_marc21json(x)
# Out:
# Record:
# 001: 999431354864702202
# 005: 20211030193533.0
# 007: ta
# 007: cr||||||||||||
# 008: 101210s1898    xx#||||| |||||000|u|ger|d
# 035:
# 	a: 943135486-47bibsys_network
# 035:
# 	a: (NO-TrBIB)943135486
# 035:
# 	a: (NO-TrBIB)100679161
# 035:
# 	a: (EXLNZ-47BIBSYS_NETWORK)999431354864702201
# 040:
# 	a: NO-TrBIB
# 	b: nob
# 	e: katreg
# 092:
# 	a: 839.822[S]
# 	q: NO-OsNB
# 	9: LOCAL
# 100:
# 	a: Ibsen, Henrik
# 	d: 1828-1906
# 	0: (NO-TrBIB)90061718
# 245:
# 	a: Henrik Ibsens sämtliche Werke in deutscher Sprache
# 	n: 3
# 260:
# 	a: Berlin
# 	b: Fischer
# 	c: [1898?]
# 300:
# 	a: XXXI, 350 s.
# 505:
# 	a: Die Helden auf Helgeland (Nordische Heerfahrt) ; Komödie der Liebe ; Die Kronprätendenten
# 533:
# 	a: Elektronisk reproduksjon
# 	b: [Norge]
# 	c: Nasjonalbiblioteket Digital
# 	d: 2010-03-22
# 600:
# 	a: Ibsen, Henrik
# 	d: 1828-1906
# 	0: (NO-TrBIB)90061718
# 	2: bare
# 700:
# 	a: Brandes, Georg
# 	d: 1842-1927
# 	0: (NO-TrBIB)90051153
# 700:
# 	a: Elias, Julius,
# 	d: 1861-1927
# 	0: (NO-TrBIB)90713803
# 700:
# 	a: Schlenther, Paul,
# 	d: 1854-1916
# 	0: (NO-TrBIB)90753256
# 740:
# 	a: Sämtliche Werke in deutscher sprache
# 773:
# 	i: Inkludert i
# 	a: Ibsen, Henrik, 1828-1906
# 	s: Verker. Tysk
# 	t: Henrik Ibsens sämtliche Werke in deutscher Sprache
# 	d: Berlin : Fischer, 1898-1904
# 	g: 3
# 	w: 999431353894702201
# 856:
# 	3: Fulltekst
# 	u: https://www.nb.no/search?q=oaiid:"oai:nb.bibsys.no:999431354864702202"&mediatype=bøker
# 	y: Nettbiblioteket
# 	z: Søke-URL
# 901:
# 	a: 80
# 913:
# 	a: Ibsensamlingen
# 	b: NB
# 787:
# 	t: NB Digital
# 	w: 81209487210002202
# 	i: Alma Collection
# AVD:
# 	0: 32210263250002202
# 	b: 0183306
# 	c: NB Digital
# 	u: http://urn.nb.no/URN:NBN:no-nb_digibok_2010021813003
# AVP:
# 	x: Status: mini - mini
# 	p: 74ga02129
# 	q: 74ga02129
# 	c: g00005
# 	z: (Til bruk på NB Oslos lesesal)
# 	0: 23199165690002202
# 	b: 0030100
# AVP:
# 	x: Status: mini - mini
# 	p: 85ga50964
# 	q: 85ga50964
# 	c: g00005
# 	z: (ib.)
# 	0: 23199165540002202
# 	b: 0030100
# AVP:
# 	x: Status: mini - mini
# 	p: 85ga06591
# 	q: 85ga06591
# 	c: g00005
# 	z: (Proveniens: Ibsenarvingene)(Oppstilt i Ibsenmuseet)
# 	0: 23199165640002202
# 	b: 0030100
# AVP:
# 	x: Status: mini - mini
# 	p: 85ga06590
# 	q: 85ga06590
# 	c: g00005
# 	z: (Proveniens: Ibsenarvingene)(Oppstilt i Ibsenmuseet)
# 	0: 23199165670002202
# 	b: 0030100
#
# Record:
# 001: 999900472104702202
# 005: 20221018124635.0
# 007: ta
# 007: cr||||||||||||
# 008: 131104s1998    no#||||| |||||000|0|nob|
# 015:
# 	a: 9906187
# 	2: nbf
# 020:
# 	a: 8251836832
# 	q: ib.
# 	c: Nkr 198.00
# 035:
# 	a: 990047210-47bibsys_network
# 035:
# 	a: (NO-TrBIB)990047210
# 035:
# 	a: (NO-TrBIB)092464866
# 035:
# 	a: (EXLNZ-47BIBSYS_NETWORK)999900472104702201
# 040:
# 	a: NO-OsNB
# 	b: nob
# 	e: katreg
# 042:
# 	a: norbibl
# 044:
# 	c: no
# 080:
# 	a: 663.91(481)
# 080:
# 	a: 061.5(481)
# 080:
# 	a: 663.91(047.3)
# 080:
# 	a: 92 Throne-Holst, Johan
# 080:
# 	a: (047.3)
# 080:
# 	a: 663
# 	2: UDC Medium edition
# 082:
# 	a: 338.76641
# 	q: NO-OsNB
# 	2: 4/nor
# 084:
# 	a: Nb 32(Jc 10)
# 	2: ubtkl/2
# 084:
# 	a: Cc
# 	2: knt
# 100:
# 	a: Ibsen, Hilde
# 	d: 1961-
# 245:
# 	a: Et lite stykke Norge :
# 	b: Freia 100 år
# 	c: Hilde Ibsen
# 260:
# 	a: [Oslo]
# 	b: Tano Aschehoug
# 	c: c1998
# 300:
# 	a: 168 s.
# 	b: ill.
# 500:
# 	a: Omhandler bl.a. Johan Throne Holst og etterkommere
# 533:
# 	a: Elektronisk reproduksjon
# 	b: [Norge]
# 	c: Nasjonalbiblioteket Digital
# 	d: 2009-05-17
# 600:
# 	a: Throne-Holst
# 	c: slekten
# 	0: (NO-TrBIB)99023016
# 	2: bare
# 600:
# 	a: Throne-Holst
# 	c: slekten
# 610:
# 	a: Freia, A/S
# 	0: (NO-TrBIB)90249112
# 	2: bare
# 653:
# 	a: industri
# 	a: oslo
# 	a: sukkervarer
# 	a: sjokolade
# 	a: industrihistorie
# 	a: næringsmiddelindustri
# 651:
# 	a: Norge
# 	2: humord
# 	0: (NO-TrBIB)HUME02605
# 650:
# 	a: Historisk framstilling
# 	2: humord
# 	0: (NO-TrBIB)HUME04097
# 650:
# 	a: Næringsmidler
# 	2: humord
# 	0: (NO-TrBIB)HUME12039
# 650:
# 	a: Industri
# 	2: humord
# 	0: (NO-TrBIB)HUME07682
# 650:
# 	a: Nytelsesmidler
# 	2: humord
# 	0: (NO-TrBIB)HUME12042
# 856:
# 	3: Forlagets beskrivelse (kort)
# 	u: https://contents.bibs.aws.unit.no/?isbn=8251836832
# 856:
# 	3: Fulltekst
# 	u: https://www.nb.no/search?q=oaiid:"oai:nb.bibsys.no:999900472104702202"&mediatype=bøker
# 	y: Nettbiblioteket
# 	z: Søke-URL
# 901:
# 	a: 90
# 913:
# 	a: Norbok
# 	b: NB
# 787:
# 	t: NB Digital
# 	w: 81209487210002202
# 	i: Alma Collection
# AVD:
# 	0: 32215186560002202
# 	b: 0183306
# 	s: 99sd06752
# 	c: NB Digital
# 	u: http://urn.nb.no/URN:NBN:no-nb_digibok_2009042804050
# AVP:
# 	x: Status: kat - kat
# 	p: 99ga03570
# 	q: 99ga03570
# 	c: g00005
# 	z: (ib.) (Til bruk på NB Oslos lesesal)
# 	0: 23153118760002202
# 	b: 0030100
# AVP:
# 	x: Status: kat - kat
# 	p: 99sa00538
# 	q: 99sa00538
# 	c: g00001
# 	0: 23153118800002202
# 	b: 0183334
# AVP:
# 	x: Status: kat - kat | NON PUBLIC NOTE: HHo  99
# 	p: 99ga17177
# 	q: 99ga17177
# 	c: g00005
# 	z: (ib.) (TAPT 20-2-2002)
# 	0: 23153118720002202
# 	b: 0030100
# AVP:
# 	x: Status: mini - mini
# 	p: 75sd64557
# 	q: 75sd64557
# 	c: g00030
# 	0: 23153118650002202
# 	b: 0183300
# AVP:
# 	x: Status: kat - kat
# 	p: 99sd25752
# 	q: 99sd25752
# 	c: g00030
# 	0: 23153118680002202
# 	b: 0183300
# AVP:
# 	x: Status: mini - mini
# 	p: 75sd64556
# 	q: 75sd64556
# 	c: g00030
# 	0: 23153118660002202
# 	b: 0183300
