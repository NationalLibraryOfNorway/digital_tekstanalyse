# %% [markdown]
# ![DHlab_logo_web_no_red.png](attachment:DHlab_logo_web_no_red.png)

# %% [markdown]
# ## Setningsuttrekk

# %% [markdown]
# Funksjonen `nb.sentence()`kan brukes til å hente setninger fra et korpus.
#
# Korpuset må bestå av minimum 5 unike urn'er.
#
# Nedenfor er eksempler på uttrekk av setninger fra bestemte forfattere. Se eksempelfil om [Korpusbygging](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/1_Bygg_korpus.ipynb) for andre måter å definere korpus.

# %%
import dhlab.nbtext as nb
from dhlab.module_update import css
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
# Her lager vi et korpus fra 10 tilfeldig utvalgte bøker utgitt fra 2000 til 2009.

nye_bøker = nb.book_corpus(period=(2000,2010), limit=10, lang='nob')

# %%
# Korpuset legges som parameter i nb-sentences

nb.sentences(nb.pure_urn(nye_bøker))
# Out:
# ['Postboks 8115 Dep , 0032 Oslo',
#  'Brudd på etikkplakatene kan klages inn for utvalget : www',
#  'Flere av blandingsmodellene med elementer av både gammel og ny finansieringsmodell vil antakelig bli endret i denne revisjonsprosessen , flere endringer er også annonsert som følge av endelige avklaringer i UFD når det for eksempel gjelder publiserings- og formidlingsinsentiver',
#  'Men hun var så vakker , så lik deg at det nesten smerter meg å se deg',
#  'Tromsø ble derfor evakuert i en periode',
#  'For å kunne klare seg best mulig med poteter til kommende vinter henstiller en til alle som har poteter utover matpotetbehovet å sette poteter i størst mulig utstrekning',
#  'Så tenk over hva dere syns om det , og hvilke endringer som eventuelt bør gjøres med veven',
#  'Potet- 09 guirofskreli FrukfskaU',
#  'Kapittel 2 - Etiske og juridiske rammer',
#  'Snu dem så de blir stekt på begge sider',
#  'Forskningskomponenten er den komponenten som har ledet til mest nytenkning',
#  'Det er et tegn på at når valget oppfattes som viktig , mobiliseres velgerne , sier han',
#  'Program Punktliste',
#  'Vi hadde 6 evakuerte fra',
#  'E-post i staten fra Høgskolen i Buskerud',
#  'ISBN 82 - 429 - 2325 - 6',
#  'Solskjær på offentlig strand',
#  'Riktignok er det ikke et stort løft å gå til valglokalet , men hvorfor ikke gjøre det så enkelt som mulig å stemme',
#  'Det gjelder også debatten om medienes egen virksomhet',
#  'Insentivene som studeres er utviklet innenfor fem hovedområder , 1 ) insentiver i form av private bidrag til å dekke utdanningskostnadene ( spesielt " tuition fees " ) , 2 ) insentiver relatert til tilgang / adgang til høgere utdanning , 3 ) insentiver som del av offentlig finansiering av høgere utdanning , 4 ) insentiver som del av offentlig finansiering av forskning og 5 ) insentiver for å stimu',
#  'En annen ting er jo at norske leverandører til de tyske styrker ut fra ordrer og rekvirerte mengder kunne se hvor mange de var i de forskjellige forlegningen Ved Macks bryggeri i Tromsø visste de nokså godt hvordan forflytningen av soldater til enhver tid foregikk',
#  'Alle sammen i snøen , sprengkulden , under stjernene , danset innunder nordlyset',
#  'Hørte stemmer som kom nærmere , og fjernet seg',
#  'Han røykte sigar , og drakk brunt brennevin fra en karaffel',
#  'Kanskje kommer man ikke lenger enn til det å forstå hvordan man er uenig',
#  'I den strategiske forskningskomponenten er det lagt opp til å synliggjøre ressursinnsatsen knyttet til rekrutteringsstillinger ved universiteter og høgskoler',
#  'De kunne ikke ta imot noe fra en nazist , og kunne heller ikke be dem inn',
#  'EGMONT SERIEFORLAGET AS',
#  'Jeg vil tro at dette kan være et interessant insentiv som vil kunne sikre at noen av de beste som forlater UoH-sektoren etter fullført Ph',
#  'Teknisk implementering Det vil si å velge plattform og utstyr og installere det , etablere spesifikasjoner og finne leverandør for nødvendig programmering , og utvikle intranettprototyp iterativt og inkrementelt',
#  'Da forsto hun også hvorfor Fiona var så fiendtlig : Hun trodde at Marie hadde vært løsmunnet',
#  'Se og Hørs advokat Hege B',
#  'Mange foreldre uttrykker bekymring for barnas store konsum av filmer , fjemsynsserier og spill med voldsinnbold',
#  'Foreldre må derfor være oppmerksomme på barnas aktiviteten Jeg anbefaler foreldrene å sette PC-en i stua slik at barna ikke surfer bak en låst dør ” ( VG , 11',
#  'Regnskapslære og bokholderi',
#  'Jeg og mamma vasket klærne og teppene',
#  'Han kjente seg maktesløs, som om det var umulig å få henne til å forstå',
#  'Serien " Reconstructions ” 2006 er en fortsettelse av " Particolare ” serien fra 2004 , hvor utgangspunktet var Venezias sanselige fargeprakt og maleriske stofflighet',
#  'Se på det nydelige halskjedet til Fiona',
#  'Som en forsmak på møtet - se på artikkelen " The Next Revolution " fra The Economist i fjor',
#  'Undervisning ved eget universitet : Omfatter tid medgått til planlegging , forberedelse og gjennomføring av alle ryper undervisning ved egen institusjon',
#  'En gang i Storgata kom det en liten tysker og antasta meg',
#  'Ellers blir man lett for sårbar til å takle utfordringene',
#  'Mediene må også ta hensyn til tobakkskadeloven og alkoholloven',
#  'Og her sitter jeg og tenker på at dette bare var min andre skoledag ,',
#  'Videre er som kjent Internett en kanal med temmelig fritt utløp for alle som har noe de ønsker å meddele omverdenen',
#  'En liten landsby gjør fremdeles motstand , de strie , ukuelige innbyggerne - gallere , selvsagt',
#  'Mye tyder på at sampubliseringer er en virkning av et økt publiseringskrav',
#  'Bøndene fikk reell makt når det',
#  'Bli enige om at det ikke skulle skjedd , at det ikke var fortjent å bli behandlet slik',
#  'Men hvorfor ser du så sur ut',
#  'Og det er handling som blir avgjørende mange ganger , tydelige oppveiende handlinger når vi har såret den andre',
#  'Vi befinner oss i år 50 før Kristus',
#  'Derfor var Mamsell så interessert i « asylludderet »',
#  'Årsaken er at elektronisk stemmegivning',
#  'Rekrutteringsstillinger',
#  'De var kommet nærmere hverandre',
#  'Også bam har rett til personvern',
#  'Prosjektplan',
#  'JASS Journal 2',
#  'Intranett - 1',
#  'Kabarbrasuppe Av rabarbra på vann',
#  'Det blir da viktig å redusere bruken av de " frie " midlene til formål som man lett kan skape konsensus rundt',
#  'I det videre vil jeg se nærmere på de fem kategoriene av insentiver',
#  'Spekesild males to ganger på kvern sammen med kokte poteter ,',
#  'FYLKESTING',
#  'Vi led vel ingen nød , men spiste stekt kålrabi',
#  'Etter krigen var alt godt , og jeg lengtet etter alt jeg hadde et pent , litt sidt taftskjørt',
#  'Utgitt av Egmont Serieforlaget AS , 0055 Oslo',
#  'Læringsteorien ; 100',
#  'Let i nettavisenes arkiver',
#  'Svimmel , holdt opp å snurre , stod stille',
#  'Loven gir videre unntak for dokumenter som inneholder opplysninger underlagt lovbestemt taushetsplikt ( § 5 a',
#  'I den sammenheng refereres en del utsagn fra personer i sentrale posisjoner innenfor presse og mediemiljø , slik de er gjengitt på trykk i dagspresse , ukepresse og fagpresse',
#  'Ingen elektroniske',
#  'Dette har skjedd :',
#  'Arbeidernes Kommunistparti ( AKP )',
#  'Tårene sprang fram i øynene hennes',
#  'For det første',
#  'ZÅP & Z ER gELfilEe- \\ / / / / NE O < s VI RUU- - ] / / / / STENPkS LIKE / J / / II I m',
#  'Piker som er løsslupne i sin omgang mens de er unge , får alltid unngjelde som voksne',
#  'Å stemme kalles ofte å utføre sin « borgerplikt »',
#  'Formål',
#  'Og mamma sa ja',
#  'Lagde mamma kakao , fikk vi smør på brødet',
#  'Men akkurat idet han hjalp Fiona på med den tykke ullkåpen , snudde han seg mot Marie og gjorde en hånlig «ikke-bry-deg-omdette»-geip',
#  'I partier',
#  'Hvordan tidsbruken i UoH-sektoren fordeler seg etter innføringen av Kvalitetsreformen vet vi ikke , men en aktuell hypotese er at tidsbruken har forskjøvet seg i retning av mer tid til undervisning og faglig veiledning',
#  'Kate Sjøveia n',
#  'Om programmet',
#  'Stemmeretten ved kommunestyre og fylkestingsvalg er noe utvidet i forhold til ved stortingsvalg , Utenlandske statsborgere som står i folkeregisteret og har bodd sammenhengende i Norge de tre siste årene før valget , har stemmerett',
#  'Dette har de senere år også rammet de nordiske kongehus , spesielt deres unge medlemmer',
#  'JEG VÅKNET , FALT TILBAKE I SØVNEN og våknet igjen',
#  'Harry Nerhagen Frøydis Solstrand Jacob Sonne',
#  'Mot 20 liter blåbær samt 20 liter tyttebær og event',
#  'Om denne skammen holder ham nede og gjør ham så uempatisk at han ikke kan uttrykke angeren , da forbanner hun denne skammen',
#  'Jeg kjente Meeka rykke i tauet',
#  'Det kjentes ikke riktig',
#  'Bruksanalysen ble gjennomført som planlagt og resultatene diskutert med den lokale prosjektgruppa',
#  'Mange vil løse problemet hvis de bare finner frem til en måte å være på lag',
#  'Gjennomvarmes , men må ikke koke',
#  'Pakket beinet inn i hard , hvit gips',
#  'Fremskrittspartiets intensjoner har Mange mener imidlertid at en rekke alltid vært at fylkeskommunenes oppgåver er for store for den enkelte oppgåver kan overlates til kommune , men likevel så lokalt primærkommunene , private og stat- forankret at de ikke bør løses på en » , står det i Fremskrittspartiets statlig nivå , De ønsker derfor å',
#  'Arkivet sender offentlig journal til et lukket Internett område',
#  'Raaen hadde bare tatt den med seg',
#  'I et parforhold som i alle andre sammenhenger betyr humoren at det fastlåste slipper taket for et øyeblikk',
#  'Vi seier ofte at media har dagsor- viktigaste mediet i valtider ,',
#  'Aktiviteter',
#  'STYRKEPRØVEN',
#  'Dagbladets sjefredaktør på dette tidspunktet , Thor Gjermund Eriksen , var naturlig nok fomøyd med resultatet , og understreket at avisen tar etikken på alvor :',
#  'Ifølge TV2 Spillmagasinet konkluderer de med at bam som spiller voldsspill kan bli negativt påvirket i form av aggressiv åtferd , men vel å merke som korttidseffekter',
#  'RV som opprinnelig var j fikk ordførarkandidaten under en allianse av AKP ( m-l ) og uavhengige nominasjonsmøtet',
#  'De satt i et stort , kjølig rom med tre inngangsdører',
#  'Den tyske kommandant i Tromsø bestemmer foreløpig : 1',
#  'Skillet er beskrevet i www',
#  'Han så ikke ut som en bonde , hadde ikke den snåle brunfargen tvers over pannen under der',
#  'Begge gjør store øyne , sier « Nei » , og jeg fortsetter : « Nei , dere ville selvfølgelig kjørt tilbake til den skadde og sørget for både førstehjelp og sårbehandling',
#  'CASE : Elektronisk dokumentutveksling i',
#  'Det var ikke meg , sa jeg jo',
#  'I dag vet leger og forskere atskillig mer om hjernen',
#  'Jeg smilte og håpet at mamma ville la meg få lov',
#  'Så langt ser det ut som om man i stor grad viderefører tanken om at det er miljøene som skal stimuleres og / eller belønnes',
#  'Qudim @',
#  'Vanlige soldater som Mo i Rana',
#  'Kapittel 11 - Tre moralverdener 103',
#  'Den egner seg ikke som alminnelig kokt fisk , men utvannet godt i to til tre dager kan forskjellige former for bacalao og karbonader være et alternativ som kan prøves',
#  'Hun følte seg så dum og utnyttet der hun',
#  'La oss se nærmere på hva det kan være',
#  'Like etter kom Engebret trampende inn og slo seg ned sammen',
#  'Marie ville gjerne være høflig',
#  'Trykt i Tyskland 2004',
#  'Videre : Hvordan er forholdet mellom finansieringssystemet og de ønskede konsekvensene',
#  'Bare de vet at de vil få sjansen , kan de gjerne vente til slutten av uken , og de slapper mye bedre av enn tidligere',
#  'Redaktørplakaten 135',
#  'Depotbiblioteket',
#  'Hun håpet jeg skulle tie stille om det',
#  'Materialet blir lagt ut på møteplanen etter som det blir ferdig',
#  'Meiningsmålingar',
#  'Arbeidstid ved univers iteter , vitenskapelige høgskoler og statlige høgskoler ( siste kolonne ) , prosentvis fordelt på oppgåver',
#  'Jeg var kald og mørk inni meg',
#  'Fiona hilste først på mor og de eldste søstrene sine , men hun spanderte likevel det bredeste fliret - guttefliret - til Marie',
#  'Her vil jeg konsentrere meg om en viktig årsak',
#  'Omstilling til nye arbeidsformer',
#  'Plakaten er per dags dato under revisjon',
#  'Følg med på valsendingar på TV',
#  'Hvordan kan vi håndtere evaluering i slike tilfeller',
#  'Slike samtaler trygges ved at du ikke blir avbrutt , men får snakke ferdig',
#  'Undervisning ved eget universitet 32 29',
#  'Unngå ukritisk videreformidling av PR-stoff',
#  'Hun',
#  'Utstillingen " Reconstructions ” 2006 består av en serie målerier , foto og objekter i glass og plexie med referanser til Villa Massimo in Laterano i Roma',
#  'Jeg og mamma',
#  'Dekninga av valkampen i media har 1995 uttalte TV Z at kanalen sjølv forandra seg mykje gjennom åra',
#  'Jeg måtte straks vise det til mamma',
#  'De var svære og røde og frodige , og da',
#  'Eller skal Erlends vasking bare legges til en annen dag enn lørdag , en dag han har bedre tid',
#  'Valgdeltakelsen blant førstegangsvelgere har alltid vært lavere enn for eldre deler av befolkningen , Hele 63 prosent av de som hadde mulighet til å stemme for første gang ved kommunestyrevalget i 2003 valgte å sitte hjemme',
#  'Reconstructions Villa Massimo - 180 x 80 cm',
#  'Samme blå tallerken',
#  'Kanskje kan man klare å legge om kursen etter dette , bare ved å finne tilbake til drømmene og finne ut hvilke drømmer som var felles',
#  'Jeg har gått opp på rommet mitt',
#  'Rakte ut handa',
#  'Han hadde passert Høybråten , og måtte subbe seg fram langs en delvis brøytet vei da han stanset nølende',
#  'DET TREDJE',
#  'Min bruk av begrepet " dilemma " ligger tettest opp til en problemorientert berydning , men det samme dilemma kan oppleves som mer eksistensielle dilemma avhengig av aktørenes ståsted',
#  'Evaluering av - og erfaringer med',
#  "På grunn av en større omorganisering ble FMVe ' s deltakere opptatt med andre gjøremål ut året",
#  'Argumentet er at stemmegivning må læres , og at det kan være en fordel å fortsatt gå på skolen når man skal stemme for første gang , Forutsetningen er da at skolen tar ansvar for en grundig demokratiopplæring',
#  'Camilla Violetta var kraftig , nesten tykkfallen , med et litt syrlig drag om munnen og med talent for å geipe',
#  'Det nasjonale finansieringssystemet for UoHsektoren gir visse føringer i forhold til intern fordeling ved institusjonene , samtidig har systemet også visse frihetsgrader',
#  'Som vi ser varierer " tilleggene " fra 7 til 13,7 %',
#  'Størst antall klager på aviser gjaldt i fjor Verdens Gang , Aftenposten og',
#  'Du vet bare om en superhelt som kan ta seg av denne',
#  'Arbeidsgruppen foreslår en trinnvis prosess der elektronisk stemmegivning festes grundig før det en gang i fremtiden kan være grunn til å tillate Intemett-stemming',
#  'Det var temmelig ensomt å være eneste person som hadde vanskelige følelser å dele i dette forholdet',
#  'Kapittel 2 - Etiske og juridiske rammer',
#  'Man får lettere kontakt om man behandler den andre på den andres premisser og uten krav',
#  'Etter lunsj presenterer gruppene forslagene for diskusjon',
#  'Arbeid med lærebøker , populærvitenskapelig virksomhet , medlemskap i styrer , komiteer , Forskningsrådet e',
#  'Og seiv da noen veier ennå var',
#  'Stiloppgåver',
#  'Til og med etter at hun ble stengt inne på sykehuset pleide Angus å se henne om natta , når hun kom med gift',
#  'Det var Pernilles tur denne morgenen , men Kajsa hadde tilbudt seg så snilt å ta Mons til barnehagen for henne fordi Pernille hadde fått en skade i benet',
#  'Vi oppfattet et slikt mandat som for snevert , og etter en dialog ble vi enig om at piloten også skulle omfatte',
#  'Det har vært en tendens de',
#  'Marie klødde over hele kroppen , så nervøs var hun',
#  'Her er stikkordene identitet og fellesskap',
#  'Ida er svært såret over dette og til tider rasende av avmakt',
#  'Kagge Forlag',
#  'Helene , på sin side , savnet « oppmerksomhet » og at de var et « team » slik som det var før',
#  'Schiøtz påpeker flere forhold som han mener bør få større oppmerksomhet :',
#  'Dette kan synes noe overraskende all den tid denne typen aktiviteter er et insentiv i seg seiv',
#  'Mange tenker kanskje at en stemme fra eller til ikke spiller noen stor rolle når det er valg , ettersom det likevel er mange som vil delta',
#  'Kjønnsmodningen kom tidligere , og barn opp til 16 år var i snitt 20 cm høyere enn barn født for 100 år siden',
#  'Let etter informasjon om 2',
#  'Bilder 157',
#  'Det vil si at 95 % av kornet skulle være med melet , mot tidligere 80 %',
#  'Han var brydd , men han gjorde ikke tegn til å gå',
#  'Bjørklund fremhever nordmenns positive oppfatning av lokaldemokratiet som et slående funn ved de tre lokalvalgsundersøkelsene som er gjennomført ,',
#  'Før sommeren 2006 søkte kommunene Porsgrunn , Vågå og Vadsø om å gi 16 - åringer stemmerett som en prøveordning ved kommunestyre- og fylkestingsvalet til høsten',
#  'Det plumpet ut av henne , hukommelsen sviktet aldri',
#  'Det var vanskelig',
#  'Fylkes- Statens øverste representant utvalget tilsvarer formannskapet i fylket er fylkesmannen',
#  'De første partiene ble stiftet i 1884',
#  'Hadde hun bare fått tid til å områ seg',
#  'For å kunne starte en radio- eller Ijemsynskanal i Norge , må man også ha offentlig konsesjon - der alle som tildeles konsesjon for riksdekkende sendinger er forpliktet til å oppfylle visse allmennkringkaster-kriterier hva programtilbudet angår',
#  'Insentiver i form av " fødselshjelpere " medfører som regel etablering av nye institusjoner eller ordninger',
#  'Grovt sett har universitetsbasert FoU disse bidragene :',
#  'Ha i salt og mel',
#  'Hele klassen så opp fra bøkene sine og fulgte med',
#  'Det er mange mater å være misfornøyd med partneren i forholdet sitt på , særlig hvis misnøyen forsterkes fordi man sammenligner med tiden og kulturens ideal',
#  'En generell konklusjon fra en studie ved Universitetet i Oslo er at aktiviteten fortsatt er i planleggingsfasen',
#  'Om styringen av denne typen satsinger kun skal tas på institusjonsnivå eller om det også skal være en viss nasjonal styring , for eksempel ved hjelp av Norges forskningsråd , er et sentralt og viktig spørsmål',
#  'For å',
#  'Eller omvendt : Man kan begynne å vise omtanke , og med det få mer medfølelse',
#  'Her følger noen forslag til stiloppgåver om medieetikk , samt hvordan Ibsen kan brukes til å belyse medieetiske problemstillinger',
#  'Men hun kom seg opp',
#  'Hun hadde fått kort fra ham , men han var så kortfattet som han pleide å være',
#  'Vi er nå ( 2004 / 5 ) midt inne i implementeringen av den nye',
#  'De var veldig høflige',
#  'Storbritania , - tyskerne myrder 11 danske sjøfolk og henviser nordens handel til mellomeuropa',
#  'Måleriene henspeiler til den praktfulle visuelle opplevelsen av farge , vegg og takmaleriene i villaen gir',
#  'Jeg hørte pappas fottrinn i trappa , og mamma som ropte ham ned igjen mens jeg stod ved senga og passet på Prins som lå og skalv under den',
#  'Basiskomponenten vil være den delen av institusjonens budsjettramme når undervisningskomponenten og forskningskomponenten er trukket fra',
#  'Derfor er det en god ting at slik organisering har en fast plass i uken',
#  'SVs stortings-',
#  'Kikket ut av vinduet',
#  'Tromsø , den 20',
#  'OED',
#  'Lysark fra gruppen',
#  'Takk til alle dere som har levert oppdateringer på systemkartleggingen',
#  'Og jeg kom til meg seiv og merket at alt var stille',
#  'En gang hadde hun vært Løwenkrons pur unge elskerinne',
#  'Hjertet stenger seg når det høres ut som om det er tiltaletenkning og anklager på gang',
#  'Her vil dere finne nyheter relatert til brukergruppen',
#  'Det hun egentlig ville si , var kanskje mer i retning av : « Du Tarjei , jeg vil være sammen med deg , være god mot deg , og vite at vi to har kontakt',
#  'Ola hadde en dreng under seg',
#  'Men så spurte hun om jeg hadde laget noen bilder med tegnearkene og fargestiftene',
#  'Vi ser det på Edvardas blikk',
#  'En annen Solveig forteller 129',
#  'Ingen av oss reiste seg',
#  'Videre kan forskere som arbeider aktivt mot næringslivet , gjennom dette arbeidet oppnå en " markedsverdi " som kan resultere i overgang til privat sektor',
#  'Og vi Irr tanken gå til alle dem son gjBr tjeneste',
#  'Det skjer noe fint mellom dem , det kjenner hun på seg',
#  'I tillegg kritiske spørsmål og velje tema',
#  'Bandwagoneffekten går ut på at folk stort sett ynskjer å vere på den vinnande sida , og at eit parti som går fram på meiningsmålingane difor trekker til seg usikre veljarar som ynskjer å stemme på det partiet som har mest framgang i augneblinken',
#  'Tekstreklameplakaten består av regler bygget på hovedprinsippet om at det skal være et klart skille mellom redaksjonelt stoff og reklame',
#  'Enkelte dager mottar Felleskjøpet opptil hundre dyr som slaktes og saltes til en pris av kroner 1',
#  'Hun reiste seg',
#  'For tre år siden regnet det',
#  'Avisen Nordlys foreslår i sitt nummer av 18',
#  'Originalens tittel : Astérix chez les Belges',
#  'Hilsen',
#  'Det er noe vedkommende seiv må kjenne på , og over litt tid : Føles det som jeg har tilgitt deg , eller bærer jeg fortsatt nag']

# %%
mykle = nb.book_corpus(author='%Mykle%Agnar%', limit=10, lang='nob')
mykle
# Out:
#              urn        author                     title  year
# 0  2008012304077  Mykle, Agnar            Samlede verker  1994
# 1  2015090129001  Mykle, Agnar  Sangen om den røde rubin  1956
# 2  2008012801029  Mykle, Agnar            Samlede verker  1994
# 3  2008020701019  Mykle, Agnar            Samlede verker  1994
# 4  2008033104009  Mykle, Agnar                   Rubicon  1996
# 5  2014021807242  Mykle, Agnar                   Rubicon  1975
# 6  2014051408203  Mykle, Agnar      Lasso rundt fru Luna  1996
# 7  2014111108298  Mykle, Agnar      Lasso rundt fru Luna  2007
# 8  2012020208192  Mykle, Agnar            Kors på halsen  1958
# 9  2014010308002  Mykle, Agnar     Morgen i appelsingult  1951

# %%
nb.sentences(nb.pure_urn(mykle), num=20)
# Out:
# ['Men det har én mangel : en ensom mann får det aldri overstått',
#  'Han er nemlig ikke en vanlig dødelig , han hører til de utvalgte , han er en av de få',
#  'Han vil tordne , spytte , tale ; men alt han har kraft til , er å trekke på skuldrene',
#  'Han reiste seg langsomt , og la merke til den lille porselensvasken i hjørnet , med beholderen av flytende såpe på veggen',
#  'Også her er veggene brunbeiset , også her er rommet stort , også her er det sperrer i taket , også her er det rare vinduer i blyinnfatning',
#  'Han visste ikke om det var fryd eller angst',
#  'Han stod alene under den enorme kveldshimlen',
#  'FØRSTE DEL',
#  'Og om jeg seiv aldri så meget har vært tilsidesatt og baktalt , så håpet jeg jo at min tid ville komme',
#  'SAMNEMNDA FOR AMATØRTEATERARBEID',
#  'Han må gripe seg rundt strupen , for den tykke , deformerte foten har ingen lilletå , det er bare en liten stump av en hvirvel igjen , det er den opererte foten hun har forfulgt ham med siden han kom hjem , den foten hun har insistert på å vise ham for at han skulle se hennes lidelser , den foten han har nektet å ville se ; nu ser han den , nu fikk hun vist den , han snur og går lydløst over gul v',
#  'Jo stod fjetret ved skrivebordet og så på henne',
#  'Ask hadde bemerket , en passant , at han syntes Villsvinsens sønn og datter var meget forskjellige , som natt og dag',
#  'Ingen mann bærer lenger en blomst i knapphullet',
#  'Hvis han holdt femti kilometer i timen',
#  'En liten dirring i huden hadde det vært hos begge to , ihvertfall hos ham ; denne lubne kontordamen med de små fregnene i ansiktets sunne hud og med den usigelig norske oppstoppernesen denne lubne litt inntilbense Synnøve med den firkantede munnen og de hvite norske tennene ; hun var som et modent eple på en gren ; eplet spurte smilende : « Plukker du meg',
#  'Et sted så han navnet Metz på et skilt',
#  'Meg , moderen',
#  'Hadde jeg ikke visst det før , så visste jeg det nu : - jeg er en av dem som øyeblikkelig ville skille seg ut , en av dem som nudiststyret omgående ville få fjernet',
#  'Hun hadde satt seg på sofaen']

# %%
sandel = nb.book_corpus(author='Sandel%Cora%', limit=5)
sandel
# Out:
#              urn        author                title  year
# 0  2013102905001  Sandel, Cora    Alberte-trilogien  2009
# 1  2007052101053  Sandel, Cora  Alberte og friheten  1965
# 2  2007081004062  Sandel, Cora     Kranes konditori  1990
# 3  2008051500038  Sandel, Cora     Alberte og Jakob  1953
# 4  2012052905120  Sandel, Cora        Sandels beste  2006

# %%
# Her legger vi setningene i en variabel som vi kan arbeide videre med

sandel_setn = nb.sentences(nb.pure_urn(sandel), num=20)
sandel_setn
# Out:
# ['Som om hun hadde noen grunn til å være bitter',
#  'Alberte rer op , slår vaskevannet ut av vinduet , så det klasker i bakken , setter et par sko på plass ved veggen og henger bort noen plagg',
#  'En hører at han skal ka vært hos den og den , siden hører en kanskje ingenting på lenge',
#  'Ett efter ett lægger Alberte vedtrærne på og kjender en vild og stærk glæde ved at se flammen slå op omkring dem',
#  'Han er hva man kaller en pen mann , korrekt , tillitvekkende , velpleiet , i sine beste år',
#  'Også Albertes går fulle , stundens høytidelighet griper henne sterkt',
#  'Men fru Selmer erklærer , at Lydia er blitt virkelig udmærket pen , og at hun ser så ladylike ut',
#  'Det kommer intet',
#  'For nå ramler',
#  'Det vil gå opp øst i Elvekroken og dreie langsomt mot syd',
#  'Få være en av dem en stund da for pokker',
#  'Jeg vil ikke mer , roper hun , jeg vil ut av dette , vi',
#  'Til hvad nytte',
#  'Itun sprinter lanFB med alle de andre , tigrer av o ^ til rop elter Big : vVlderte « takkar — lr ^ ken Belnier — kull , la nenne ikke kornine lrein , tenk oni — kan ikke noen —',
#  'Jeg har , som sagt , talt endel med Bremer , han finder —',
#  'Du skal bare ikke vør at gjøre deg naivere enn du er',
#  'Et rykte på Montparnasse vil vite at han på et tidlig stadium blev avsløret som Tysklands spion og skutt , et annet at han simpelthen er forsvunnet som mange andre',
#  'Det er som var han ikke bare vennlig stemt mot Gjør ,',
#  'Så går nun sin vei med uret , styrter avsted langs våte , glinsende fortau , vel vitende at hun er ute i siste øyeblikk',
#  'Stordal får plutselig den hårde stemmen sin']

# %%
# Skriv setningene ut til en .txt-fil

with open('setninger.txt', 'w', encoding='utf-8') as f:
    for setning in sandel_setn:
        f.write(setning)
        f.write('\n')
