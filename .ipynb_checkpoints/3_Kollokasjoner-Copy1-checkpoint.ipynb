# %% [markdown]
# ![DHlab_logo_web_no_red.png](attachment:DHlab_logo_web_no_red.png)

# %%
import dhlab.graph_networkx_louvain as gnl
import dhlab.nbtext as nb
import networkx as nx
# %matplotlib inline
import dhlab.module_update as mu
import warnings
warnings.filterwarnings('ignore')
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# # Kollokasjoner eller assosiasjoner
#
# I denne notebooken viser vi eksempler på undersøkelser man kan gjøre for å finne ut hvilke ord et ord opptrer sammen med innenfor et korpus.

# %% [markdown]
# ## 1. Konstruer et korpus med Dewey
#
# Se eksempelfil om [Korpusbygging](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/1_Bygg_korpus.ipynb) for andre måter å definere korpus.
#
# For å finne relevant dewey-klassifikasjon kan [Webdewey](http://deweysearchno.pansoft.de/webdeweysearch/index.html) være til god hjelp.

# %%
# korpus med inntil 200 bøker fra dewey 641.2 (drikkevarer) utgitt mellom 1960 og 2020

korpus = nb.book_urn(ddk='641.2%', period=(1960, 2020), limit=200)

# %% [markdown]
# Kommandoen nb.frame() kan benyttes på en hel del output. Gir en fin oversikt over data, og kan brukes .head() for å se de første eksemplene.

# %%
nb.frame(korpus).head(10)
# Out:
#                0                        1  \
# 0  2010062808033        Olaf-Hansen, Erik
# 1  2011022403023           Bølgen, Toralf
# 2  2014061848144               Bø, Merete
# 3  2016102748002           Hagerup, Klaus
# 4  2016072948039  Johansen, Vidar Kenneth
# 5  2011032108037         Jørgensen, Helge
# 6  2013121305020      Teien, Thor Richard
# 7  2010061603006            Laurin, Urban
# 8  2016010807509            Gravdal, Tove
# 9  2011021603028           Salvesen, Geir
#
#                                            2     3
# 0                                  Drikk vin  1995
# 1  Bølgen &amp; Mois store bok om mat og vin  2010
# 2                        Vinens vinnere 2010  2009
# 3            Svarte haner &amp; ville griser  2005
# 4                                 Spansk vin  2005
# 5                         Ansvarlig vertskap  2003
# 6                  Hva skal vi ha i glasset?  1979
# 7                     Whisky fra hele verden  1998
# 8                         Ett år i Champagne  2002
# 9                    Himmelske kombinasjoner  2010

# %% [markdown]
# ## 2. Lager kollokasjoner fra korpuset
#
# Et skrittvis eksempel.
# 1. Bygg kollokasjonen
# 2. Finn en referanse
# 3. Sammenlign kollokasjon med referanse

# %% [markdown]
# ### 2.1. Bygg kollokasjon
#
# Kommandoen er `urn_coll()`. Legg gjerne inn en sjekk med konkordans.

# %%
collword = 'rødvin'

# %%
# Vi utfører en konkordans for å sjekke at korpuset virker.

nb.urn_concordance(word = 'sei', urns = korpus, size = 5)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022403023?searchText=sei' target='_blank' style='text-decoration:none'>Bølgen &amp; Mois store bok om mat og vin, Bølgen, Toralf, 2010</a>
#                 </td>
#                 <td>eksempel torsk , steinbit eller</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>1 gulrot</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022403023?searchText=sei' target='_blank' style='text-decoration:none'>Bølgen &amp; Mois store bok om mat og vin, Bølgen, Toralf, 2010</a>
#                 </td>
#                 <td>1 kg hvit fisk som</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>, lyr og torsk uten</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022403023?searchText=sei' target='_blank' style='text-decoration:none'>Bølgen &amp; Mois store bok om mat og vin, Bølgen, Toralf, 2010</a>
#                 </td>
#                 <td>Ristet</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>med chablis-sjy og frisk grønn</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011022403023?searchText=sei' target='_blank' style='text-decoration:none'>Bølgen &amp; Mois store bok om mat og vin, Bølgen, Toralf, 2010</a>
#                 </td>
#                 <td>Ristet</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>med chablis-sjy og frisk grønn</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012120738006?searchText=sei' target='_blank' style='text-decoration:none'>Håkan Larssons fredagskveld med mat og vin, Larsson, Håkan., 2011</a>
#                 </td>
#                 <td>benfri ryggfilet av torsk ,</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010042803033?searchText=sei' target='_blank' style='text-decoration:none'>Vin til maten, Ornäs, Catarina Hiort af, 1995</a>
#                 </td>
#                 <td>fiskekoteletter ( av torsk ,</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>eller hellefisk )</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010050403066?searchText=sei' target='_blank' style='text-decoration:none'>Historien om de norske akevitter, Dege, Hroar, 1997</a>
#                 </td>
#                 <td>markedet for norsk klippfisk av</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>, lange eller torsk og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014030308128?searchText=sei' target='_blank' style='text-decoration:none'>To på reise, Opsahl, Nils H., 2001</a>
#                 </td>
#                 <td>: - Den første som</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>fetta no , får med</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010091403017?searchText=sei' target='_blank' style='text-decoration:none'>Champagne og musserende vin, Stevenson, Tom, 1999</a>
#                 </td>
#                 <td>, es cce c V</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>__ & & ill 1</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013091638066?searchText=sei' target='_blank' style='text-decoration:none'>Basic vin, Hess, Reinhardt, 2004</a>
#                 </td>
#                 <td>At de i vinsmakingsprøver har</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>ret over viner fra den</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013022738026?searchText=sei' target='_blank' style='text-decoration:none'>Akevittviseboken, , 2009</a>
#                 </td>
#                 <td>nys å ætter på så</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>dæm at dæm træng mæ</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008022900003?searchText=sei' target='_blank' style='text-decoration:none'>Kva skal vi ha i glaset?, Teien, Thor Richard, 1995</a>
#                 </td>
#                 <td>under , er vanskeleg å</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>men alkoholmisbruk var eit alvorleg</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008101304043?searchText=sei' target='_blank' style='text-decoration:none'>Nybegynnerens vinbok, Clarke, Oz, 2000</a>
#                 </td>
#                 <td>Betegnelsene er</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>semiseco og dulce</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016030248188?searchText=sei' target='_blank' style='text-decoration:none'>Fisk og vin, , 2001</a>
#                 </td>
#                 <td>som makrell , torsk ,</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>og forskjellige flyndrefisker . Silden</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061305064?searchText=sei' target='_blank' style='text-decoration:none'>Vin til glede, Price, Pamela Vandyke, 1976</a>
#                 </td>
#                 <td>, kolje , slettvar ,</td>
#                 <td>sei</td>
#                 <td style='text-align:left'>, flyndre , lysing ,</td>
#             </tr>
# </table>

# %% [markdown]
# Så kan vi hente ut selve kollokasjonen, dvs. ord som står innenfor en viss avstand fra målordet.

# %%
# Vi legger inn variablen collword som søkeord, med 5 ord før og etter. 
#  Antall ord før og etter kan endres etter konteksten man vil undersøke.
# Collword er lagt som variabel i cella over, slik at det er lett å gjenbruke notebooken for ulike søkeord

coll = nb.urn_coll(collword, urns = korpus, after = 5, before = 5, limit = 1000)

# %% [markdown]
# Kollokasjonen ligger i en såkalt **dataframe** som kan undersøkes med `.head()` som ovenfor.

# %%
coll.head(10)
# Out:
#         0
# ,    3445
# .    3113
# og   2004
# en   1947
# er   1229
# av   1076
# som  1005
# med   985
# i     982
# til   787

# %% [markdown]
# ### 2.2. Finn referanse
#
# Det er flere måter å sammenligne på. En er å bruke bokhylla selv om som referanse. For å hente ut ord fra bokhylla brukes kommandoen `totals(<antall ord>)`. Korpuset selv kan også benyttes, for eksempel med kommandoen `aggregate_urns(<korpusdefinisjon>)`.

# %% [markdown]
# #### 2.2.1. Bokhylla aggregert

# %%
tot = nb.frame(nb.totals(top = 50000))

# %%
tot.head()
# Out:
#               0
# .    1265723110
# ,    1105303412
# og    543432056
# i     460246057
# det   273411583

# %% [markdown]
# #### 2.2.2. Aggregert korpus

# %%
korpus_agg = nb.aggregate_urns(korpus)

# %% [markdown]
# Gjør den om til dataramme, sorterer og ser på resultatet
# 1. Dataramme med kommando `frame()`
# 2. Sortering med `frame_sort()` definert øverst i den her notebooken.

# %%
korpus_agg = nb.frame_sort(nb.frame(korpus_agg))

# %%
korpus_agg.head(10)
# Out:
#           0
# ,    726324
# .    607377
# og   370316
# i    284037
# er   222791
# av   189591
# som  184028
# en   155422
# med  126502
# til  124112

# %% [markdown]
# ### 2.3. Sammenlign

# %% [markdown]
# Vi har nå tre frekvenslister som kan sammenlignes med hverandre. For å lette sammenlign normaliseres dem. Kommandoen for normalisering er `normalize_corpus_dataframe(<frekvensliste>)`

# %%
nb.normalize_corpus_dataframe(korpus_agg)
nb.normalize_corpus_dataframe(tot)
nb.normalize_corpus_dataframe(coll)
# Out:
# True

# %% [markdown]
# Inspiser dataene etter normalisering

# %% [markdown]
# #### 2.3.1. Aggregert korpus
#
# Fyll inn verdier for `.head()` for å se mer.

# %%
korpus_agg.head()
# Out:
#            0
# ,   0.054256
# .   0.045370
# og  0.027662
# i   0.021217
# er  0.016642

# %% [markdown]
# #### 2.3.2. Bokhylla total

# %%
tot.head()
# Out:
#             0
# .    0.058921
# ,    0.051453
# og   0.025297
# i    0.021425
# det  0.012728

# %% [markdown]
# #### 2.3.3. Kollokasjonen

# %%
coll.head()
# Out:
#            0
# ,   0.059955
# .   0.054177
# og  0.034876
# en  0.033884
# er  0.021389

# %% [markdown]
# Kollokasjonen *coll* har gjennomgående høyere verdier, noe som sannsynligvis skyldes at det er færre ord.

# %% [markdown]
# #### 2.3.4. Utfør sammenligning
#
# For sammenligning måles forskjellen på *coll* med referansen. Forskjellen måles ved å dividere hvert ords frekvens ikollokasjonen på frekvensen ordet har i referansen.
#
# $$\textrm{assosiasjons-styrke}(w) = \frac{\textrm{coll}(w)}{\textrm{referanse}(w)}$$
#
# Divisjonen pr.ord gjøres av Python - resultat sorteres og legges i variabelen `coll_assoc`

# %%
coll_assoc = nb.frame_sort(coll**1.0/tot)

# %%
coll_assoc.head(20)
# Out:
#                         0
# hvitvin       3960.007603
# Bordeaux       749.996046
# Kraftig        648.341667
# rødvin         625.999418
# fyldig         547.608600
# drikkes        439.053763
# Chateau        406.225363
# druer          352.523613
# saftig         325.682828
# portvin        323.403356
# portugisisk    320.591818
# druene         291.644766
# viner          272.901658
# vinene         267.884723
# Enkel          240.791292
# Vinmonopolet   238.943899
# Frisk          237.349713
# Spanias        216.315090
# Blanc          214.727662
# Italiensk      211.644153

# %% [markdown]
# #### 2.3.5. Sammenlign med korpus
#
# Her kan det være nyttig å bruke en eksponent for å dempe effekten av lavfrekvente ord.

# %%
coll_assoc_korp = nb.frame_sort(coll**1.2/korpus_agg)

# %%
coll_assoc_korp.head(20)
# Out:
#                             0
# Karbonader         111.737456
# bodeaux             59.797533
# vintype:            59.797533
# T3IH1in             59.797533
# Suffleer            59.797533
# tilberedningsform   44.890174
# Fettstrukturen      44.813996
# fiskefettet         44.694982
# Fordeling           38.648895
# jordbærsmakende     37.245819
# Insisterer          34.344664
# Grønnsakterter      34.344664
# tanninsvak          33.610497
# fordre              33.610497
# anbefale.           32.424368
# Genfersjøen.        32.424368
# fiskekjøttet,       32.424368
# tyktflytende,       32.424368
# plommemoden         29.898767
# Viaders             29.898767

# %% [markdown]
# # 3. Visualiser med en ordsky
#
#
# Visualiseringen trives best med tall mellom 0 og 1, så assosiasjonene divideres på summen av dem for å få til det. Ordskyene lages med kommonandoen `cloud(<data>)`. Pass på å ikke ta med alt for mange; det kan gi feilsituasjoner.

# %%
# Her viser vi de 50 viktigste ordene som er assosiert med rødvin i korpuset vårt, målt mot alle bøker i nb.no 

nb.cloud(coll_assoc.head(50)/coll_assoc.sum())

# %%
# Her viser vi de 50 viktigste ordene som er assosiert med rødvin, målt mot hele "Drikkevare"-korpuset

nb.cloud(coll_assoc_korp.head(50)/coll_assoc_korp.sum())

# %% [markdown]
# ## 4. Gjenbruk med andre ord og korpus

# %% [markdown]
# 1. Bytt ut parametrene i cellen der `korpus` blir definert.
# 2. Bytt ut ordet som er angitt som `collword`.
# 3. Gå til `Cell` i menyen og velg `Run All`.
#
# Det er også mulig å først velge `File` og `Make a Copy`, slik at man oppretter en ny notebook før man starter.

# %% [markdown]
# Tilbake til [DHLAB ved Nasjonalbiblioteket](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/DHLAB_ved_Nasjonalbiblioteket.ipynb)
