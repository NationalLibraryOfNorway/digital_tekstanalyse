# %%
import dhlab as dh
from dhlab.api.nb_ngram_api import make_word_graph
from dhlab import graph_networkx_louvain as gnl

# %%
is_ = make_word_graph('is')

# %%
gnl.show_graph(is_, spread= 5)

# %%
gnl.show_communities(is_)
# Out:
# is-snø :  is, snø, sne, holke, sno, hålke, Snø, dugg, skare, Sno, regn, Eld, sludd, slaps, tomkasser, Kulde, siles, kuldegrader, Ski, hardpakket, isdekke, hagl, ,, glatt, granskog, avkjøles, tomtønner, skummes, rim, kondens, slud, Glod, eld, ski, barfrost, ), isete, kornsne, Vatn, vanskelige, minusgrader, Vinter, dårlig, fokksnø, papir, stov, snøbyger, ising, Agnsild, isdannelse, skiføre, Sludd, nysne, allmennkunnskaper, sjøis
#
# Sne-Is :  Sne, Is, Storm, Hagel, Regn, Frost, Slud, Hagl, lis
#
# sørpe-ild :  sørpe, ild, Blod, vann, snøslaps, svovel, røyk, småstykker, overvann, isvann, røk, isflak, søle, rok
#
# kulde-frost :  kulde, frost, vind, væte, snestorm, sult, fuktighet, mørke, varme, snøstorm
#
# hav-fjell :  hav, fjell, fjord, land, himmel, kyst, kontinenter
#
# pølser-brus :  pølser, brus, mineralvann, kaffe, kaker, vørterøl, pinnebrød, godteri, hamburgere, Pølser, polser, pizza, øl, snacks, opskjær, burgere, lettøl, karbonader, Kaffe, skinker, hamburgarar, boller, koteletter
