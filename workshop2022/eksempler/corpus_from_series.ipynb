# %%
import dhlab as dh
import pandas as pd

# %%
def corpus_from_series(s = pd.Series, from_year=1945, to_year=1978):
    
    c = dh.text.corpus.EmptyCorpus()
    
    for avis in s:        
        avis = (avis.lower()
                    .replace(' ', '')
                    .replace('æ', 'ae')
                    .replace('ø', 'o')
                    .replace('å', 'aa')
                    .replace('-', ''))
        
        new_corpus = dh.Corpus(doctype='digavis', title=avis, from_year=from_year, to_year=to_year , limit=100)
 
        c.add(new_corpus)     
        
        
    return c

# %%
partipressen = pd.read_csv('partipressen.csv')

# %%
høyre_liste = list(partipressen.loc[partipressen['parti'] == 'Høyre', 'avis'])

# %%
c = corpus_from_series(høyre_liste)
# Out:
# 41
# 4
# christiansandstidende: zero length
# drammenstidende: zero length
# finmarksposten: zero length
# fredrikstadblad: zero length
# grimstadadressetidende: zero length
# hamarstiftstidende: zero length
# moredagblad: zero length
# stavangeren: zero length
# indresmaalenenesavisogopplandstidende: zero length

# %%
c.corpus
# Out:
#         dhlabid                                                urn  \
# 0   200007419.0  URN:NBN:no-nb_digavis_adresseavisen_null_null_...
# 1   202905655.0  URN:NBN:no-nb_digavis_adresseavisen_null_null_...
# 2   200006900.0  URN:NBN:no-nb_digavis_adresseavisen_null_null_...
# 3   202910578.0  URN:NBN:no-nb_digavis_adresseavisen_null_null_...
# 0   202975607.0  URN:NBN:no-nb_digavis_aftenposten_null_null_19...
# ..          ...                                                ...
# 3   201356442.0  URN:NBN:no-nb_digavis_ostlandetsblad_null_null...
# 0   200951415.0  URN:NBN:no-nb_digavis_lofotposten_null_null_19...
# 1   200954228.0  URN:NBN:no-nb_digavis_lofotposten_null_null_19...
# 2   200946319.0  URN:NBN:no-nb_digavis_lofotposten_null_null_19...
# 3   200948324.0  URN:NBN:no-nb_digavis_lofotposten_null_null_19...
#
#              title authors oaiid sesamid isbn10          city   timestamp  \
# 0    adresseavisen    None  None    None   None     Trondheim  19580113.0
# 1    adresseavisen    None  None    None   None     Trondheim  19451016.0
# 2    adresseavisen    None  None    None   None     Trondheim  19560427.0
# 3    adresseavisen    None  None    None   None     Trondheim  19700225.0
# 0      aftenposten    None  None    None   None          Oslo  19591208.0
# ..             ...     ...   ...     ...    ...           ...         ...
# 3   ostlandetsblad    None  None    None   None  Nordre Follo  19460925.0
# 0      lofotposten    None  None    None   None         Vågan  19651015.0
# 1      lofotposten    None  None    None   None         Vågan  19750410.0
# 2      lofotposten    None  None    None   None         Vågan  19480927.0
# 3      lofotposten    None  None    None   None         Vågan  19550711.0
#
#       year publisher langs subjects   ddc genres literaryform  doctype
# 0   1958.0      None  None     None  None   None         None  digavis
# 1   1945.0      None  None     None  None   None         None  digavis
# 2   1956.0      None  None     None  None   None         None  digavis
# 3   1970.0      None  None     None  None   None         None  digavis
# 0   1959.0      None  None     None  None   None         None  digavis
# ..     ...       ...   ...      ...   ...    ...          ...      ...
# 3   1946.0      None  None     None  None   None         None  digavis
# 0   1965.0      None  None     None  None   None         None  digavis
# 1   1975.0      None  None     None  None   None         None  digavis
# 2   1948.0      None  None     None  None   None         None  digavis
# 3   1955.0      None  None     None  None   None         None  digavis
#
# [124 rows x 17 columns]
