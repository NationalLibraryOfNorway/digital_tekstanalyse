# %% [markdown]
# ![DHlab_logo_web_no_red.png](attachment:DHlab_logo_web_no_red.png)

# %% [markdown]
# ### Oppstart
#
# Henter ut en kommando fra `nbtext` for å søke på jokertegn i dataene.

# %%
from dhlab.nbtext import sorted_wildcardsearch
from dhlab.module_update import css
css()
# Out:
# <style>@import url(http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Shippori+Mincho|Istok+Web|Philosopher|Assistant:200,400,700);
#
# p {
#     font-size:1.3em;
#     font-family:serif;
#     line-height:1.4em;
#     color:#142850;
# }
# h1, h2, h3, h4 {
#     color:#27496d;
# }
#
# /*
# .prompt, .jp-InputPrompt, .jp-InputArea-prompt, .jp-OutputPrompt, .jp-OutputArea-prompt {
#     visibility: hidden;
# }
#
#
# .jp-CodeCell .jp-Notebook-cell    {
#     margin-left:10%;
#     margin-right:5%;
# }
#
#
# .jp-InputArea, .jp-OutputArea {
#     margin-left:2.5em;
#     margin-right:2.5em;
# }
# */
#
#
# body  {
#     margin:10%;
#     counter-reset: h1counter;
#
# }
#
# /* .jp-MarkdownOutput, .text_cell_render {
#
#     background-color:#FEFBF1;
#     border-style: solid;
#     border-width: 1px;
#     border-color: rgba(0,0,0, 0.10);;
# } */
#
#
# h1:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 50%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:3px solid SlateGray; /* FireBrick; */
# }
#
# h2:after {
#     content: ""; /* This is necessary for the pseudo element to work. */
#     display: block; /* This will put the pseudo element on its own line. */
#     /*margin: 0 auto; This will center the border. */
#     width: 30%; /* Change this to whatever width you want. */
#     padding-top: 10px;
#     border-bottom:2px solid SlateGray; /* FireBrick; */
# }
#
# </style>

# %% [markdown]
# ## Trunkering

# %% [markdown]
# Trunkering er nyttig til flere søk i det digitaliserte materialet. Her viser vi eksempler på hvordan trunkererte søk kan brukes for å finne
# 1. [OCR](https://snl.no/OCR_-_IT)-feil eller stavelsesvarianter
# 2. bøyningsformer
# 3. sammensetninger

# %% [markdown]
# ### Legg inn ordet det søkes etter med * for åpne plasser.
#
#
# Søket etter ord blir som søk med * som jokertegn. Parameteret *factor* bestemmer størrelsen på søket, og vil gi en slags [Levenshtein-effekt](https://en.wikipedia.org/wiki/Levenshtein_distance). Øk verdien på `factor` for å finne sammensetninger eller bøyningsformer.
#
# Om jokertegnet står først genereres en feil, så søket må startes med en eller flere bokstaver, jo fler bokstaver i starten, desto raskere går søket.

# %% [markdown]
# #### Se etter OCR-feil

# %%
sorted_wildcardsearch(
    {
        'word': 'Kj*lig*d',   # her legges selve søkeordet inn
        'factor':3,           # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':50,        # sett begrensninger på frekvensen, minimumsverdi
        'limit':50            # begrensning på antall treff
        
    })
# Out:
#        Kj*lig*d
# status     feil

# %% [markdown]
# #### Finn bøyningsformer

# %%
sorted_wildcardsearch(
    {
        'word': 'barn*',   # her legges selve søkeordet inn
        'factor':2,        # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':50,     # sett begrensninger på frekvensen, minimumsverdi
        'limit':50         # begrensning på antall treff
        
    })
# Out:
#            barn*
# barn     7510973
# barnet   2434370
# barna    2410483
# barnets   526760
# barns     383517
# barnas    271674
# barndom   195602
# barne-    131835
# barne      28490
# barnen     27716
# barnlig    26706
# barnene    26556
# barnløs    18681
# barneår    10924
# barn-       8056
# barnens     7595
# barnet.     5541
# barneog     5304
# barnet,     4662
# barnetB     2219
# barnål      2138
# barnleg     1830
# barnl       1596
# barnB       1370
# barner      1324
# barnel      1272
# barnes      1231
# barnsøl     1213
# barnaB      1163
# barna.      1155
# barni       1137
# barnef      1114
# barnlos      986
# barna,       890
# barnek       774
# barned       757
# barnn        716
# barnit       710
# barnev       663
# barneh       591
# barnetß      534
# barns-       512
# barneha      480
# barnhem      472
# barneb       472
# barndåp      463
# barnat       460
# barnlss      451
# barnete      437
# barnan       397

# %% [markdown]
# #### Finn sammensetninger

# %%
sorted_wildcardsearch(
    {
        'word': 'sitron*',   # her legges selve søkeordet inn
        'factor':6,          # factor bestemmer hvor mye lenger treffene skal være enn ordet med jokertegn.
        'freq_lim':50,       # sett begrensninger på frekvensen, minimumsverdi
        'limit':50           # begrensning på antall treff
        
    })
# Out:
#                sitron*
# sitron           73502
# sitronsaft       64812
# sitroner         14599
# sitronskall      13843
# sitronsyre        7600
# sitronen          6345
# sitronsaften      5538
# sitronbåter       5167
# sitron-           4797
# sitrongress       4604
# sitronskiver      4598
# sitronmelisse     4405
# sitronskive       3920
# sitronene         2757
# sitrongul         2723
# sitrongule        2384
# sitronbrus        2282
# sitronjuice       2072
# sitronskallet     1973
# sitrongult        1701
# sitronsmak        1316
# sitronsaus        1177
# sitronolje         982
# sitrontre          977
# sitrontrær         970
# sitronbåt          969
# sitronpepper       955
# sitronvann         843
# sitrontimian       833
# sitronar           789
# sitronkake         699
# sitronsaft.        637
# sitrondråper       597
# sitrondrops        585
# sitronsaft,        584
# sitronskivene      578
# sitronkrem         574
# sitrontreet        519
# sitrontrærne       478
# sitrongresset      460
# sitronskal         446
# sitronpai          444
# sitronpresse       437
# sitronskiven       425
# sitronaktig        409
# sitronfromasj      386
# sitrontwist        382
# sitronverbena      372
# sitronsyren        357
# sitronduft         354

# %% [markdown]
# Tilbake til [DHLAB ved Nasjonalbiblioteket](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/DHLAB_ved_Nasjonalbiblioteket.ipynb)
