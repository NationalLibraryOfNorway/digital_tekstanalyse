# %% [markdown]
# ![DHlab_logo_web_no_red.png](attachment:DHlab_logo_web_no_red.png)

# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl
import pandas as pd
from dhlab.module_update import update, css, code_toggle
# %matplotlib inline

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# ...

# %% [markdown]
# ## 1. Hente ut ordparadigmer
# For å hente ut ordparadigmer kan vi bruke funksjonen `nb.word_paradigm('ord')`
# Resultatet blir alle formene for dette ordet, hentet fra [Norsk Ordbank.](https://www.nb.no/sprakbanken/show?serial=oai%3Anb.no%3Asbr-5&lang=nb)
#
# Eksempler:

# %%
nb.word_paradigm("meter")
# Out:
# [['subs', ['meter', 'meteren', 'meterne']]]

# %%
# Vi kan også legge dette i en variabel, som vi kan se på

søster = nb.word_paradigm('søster')
søster
# Out:
# [['subs', ['søster', 'søstera', 'søsteren', 'søstre', 'søstrene', 'søstrer']]]

# %%
# Eksempel med ord som er både adjektiv, substantiv og verb

fisker =  nb.word_paradigm('fisker')
fisker
# Out:
# [['adj', ['fiska', 'fiskede', 'fiskende', 'fisket', 'fiskete']],
#  ['subs',
#   ['fisk',
#    'fisken',
#    'fiskene',
#    'fisker',
#    'fiska',
#    'fiske',
#    'fisket',
#    'fiskere',
#    'fiskeren',
#    'fiskerer',
#    'fiskerne']],
#  ['verb', ['fisk', 'fiska', 'fiske', 'fisker', 'fiskes', 'fisket']]]

# %% [markdown]
# ### 1.1. N-gram for ordparadigmene

# %% [markdown]
# For en introduksjon til n-gram, se eksempelfil om [N-gram og galakser](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/4_N-gram_og_galakser.ipynb) eller [NB N-gram.](https://www.nb.no/sp_tjenester/beta/ngram_1/)
#
# Her har vi en funksjon som viser ngram for ordene i word_paradigm, `paradigme_ngram`.
#
# `y=` definerer hvilken av ordgruppene vi får ut. Default er satt til 0.
# `z=` her kan vi angi ord utenfor paradigmet som vi også ønsker å undersøke.

# %%
paradigme_ngram = lambda x, y =0, z='': nb.nb_ngram(','.join(nb.word_paradigm(x)[y][1]+[z])).plot(figsize=(10,5),lw=(3))

# %%
paradigme_ngram("søster", y=0, z='')

# %% [markdown]
# Tilbake til [DHLAB ved Nasjonalbiblioteket](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/DHLAB_ved_Nasjonalbiblioteket.ipynb)
