# %% [markdown]
# ![resources/images/dhlab-logo-nb.png](../resources/images/dhlab-logo-nb.png)

# %% [markdown]
# # Frekvenslister
# Frekvenslister fra tekster kan danne utgangspunkt for mye informasjon om teksten.
#
# Her bruker vi klassen `Counts` for å hente frekvensklister (absoluttfrekvenser) fra boka.
#
# `urn`er identifikator for boka i Nasjonalbibliotekets samling. Under eksempelfila om korpusbygging() finnes mer informasjon om hvordan man bygger et korpus. Urn finner man i bokas metadata, og de er på denne formen: https://urn.nb.no/URN:NBN:no-nb_digibok_2012051608012. Det er de 13 sifrene på slutten vi bruker her.

# %%
from dhlab import Counts, totals, Corpus
import dhlab.graph_networkx_louvain as gnl
import pandas as pd
import dhlab.nbtext as nb

# %% [markdown]
# ### Frekvensliste for enkeltbøker

# %% [markdown]
# #### Kort sakprosabok

# %%
urn = "URN:NBN:no-nb_digibok_2021011848587"
bok = Counts([urn])

# %%
bok.frame.iloc[:, 0]
# Out:
# ,                   184
# .                   162
# og                   94
# i                    93
# det                  51
#                    ...
# ekstra                1
# eget                  1
# egenkjærligheden      1
# egenflige             1
# eneste                1
# Name: 100431574, Length: 1597, dtype: int64

# %% [markdown]
# Vi kan sammenlikne frekvenslista for boka med et større korpus, som vi her legger i variabelen tot

# %%
tot = totals()

# %% [markdown]
# Vi lager en dataramme, `nb.frame()` for forholdet mellom frekvensene for ordene i vann og for de 50000 mest frekvente ordene i hele nb.no

# %%
(bok.frame.iloc[:, 0] / tot.iloc[:, 0]).sort_values(ascending=False).head(20)
# Out:
# Hedda          0.000050
# def            0.000030
# Ivo            0.000026
# Skjønberg      0.000023
# Claes          0.000019
# Gill           0.000017
# oppførelse     0.000016
# teatrene       0.000016
# VAN            0.000015
# væsen          0.000013
# Alten          0.000013
# Rosenkrantz    0.000011
# Kaas           0.000011
# poetiske       0.000010
# ensemblet      0.000010
# Høst           0.000010
# Jæger          0.000010
# kontra         0.000009
# Peggy          0.000009
# Vauxhall       0.000009
# dtype: float64

# %%
tot
# Out:
#                     freq
# .             7655423257
# ,             5052171514
# i             2531262027
# og            2520268056
# -             1314451583
# ...                  ...
# tidspunkter       110667
# dirigenter        110660
# ondartet          110652
# kulturtilbud      110652
# trassig           110651
#
# [50000 rows x 1 columns]

# %% [markdown]
# #### Knausgårds *Min kamp / Første bok*

# %%
min_kamp_1 = Counts(["URN:NBN:no-nb_digibok_2014032405041"])
min_kamp_1.frame.head(20)
# Out:
#        100197175
# ,          14332
# .           9480
# og          5383
# det         4430
# jeg         4175
# i           3657
# var         3238
# på          3152
# -           2500
# som         2463
# en          2175
# hadde       2010
# ikke        1947
# av          1900
# den         1895
# til         1815
# med         1787
# sa          1705
# meg         1581
# å           1575

# %%
(min_kamp_1.frame.iloc[:, 0] / tot.iloc[:,0]).sort_values(ascending=False).head(20).to_frame("ratio")
# Out:
#                ratio
# Yngve       0.000572
# Farmor      0.000376
# pappas      0.000231
# farmor      0.000203
# Ylva        0.000190
# skrudde     0.000154
# Jada        0.000130
# Fløgstad    0.000119
# helte       0.000114
# koppen      0.000108
# kroppene    0.000108
# gitaren     0.000105
# jævla       0.000105
# rekkverket  0.000104
# cola        0.000103
# røykte      0.000101
# sigaretten  0.000101
# kløv        0.000097
# faen        0.000094
# stuen       0.000090

# %% [markdown]
# ### Sammenlikning av frekvens for ulike bøker

# %%
# Frekvenslisiter for 20 Anne-Cath. Vestly bøker
vestly = Counts(
    Corpus(
        author="Anne*Vestly*",
        limit=20
    )
)
vestly.frame.head()
# Out:
#      100503685  100503477  100503478  100516696  100445919  100440922  \
# ,       3361.0     1877.0     1933.0       46.0     2741.0     2279.0
# og      2794.0     1114.0     1290.0       32.0     1631.0     1588.0
# .       2528.0     1664.0     1840.0       42.0     2365.0     2079.0
# var     1531.0      458.0      587.0        9.0      691.0      660.0
# det     1320.0      699.0      841.0       18.0      949.0      863.0
#
#      100558943  100401171  100566074  100463823  100031786  100035823  \
# ,       2088.0     1356.0     2316.0     2726.0     2087.0      365.0
# og      1389.0      915.0     1479.0     1475.0     1387.0      229.0
# .       1979.0     1276.0     1734.0     2378.0     1983.0      330.0
# var      622.0      293.0      704.0      700.0      621.0       75.0
# det      775.0      504.0      831.0      999.0      776.0      135.0
#
#      100039821  100124378  100164506  100495412  100235984  100325187  \
# ,        426.0     2745.0     1330.0      578.0     2904.0     2082.0
# og       237.0     1616.0     1146.0      466.0     1640.0     1384.0
# .        435.0     1969.0     1932.0      688.0     2665.0     1992.0
# var       91.0      617.0      459.0       81.0      649.0      623.0
# det      132.0      867.0      642.0      196.0      925.0      775.0
#
#      100351724  100387104
# ,         39.0     2039.0
# og        14.0     1336.0
# .         45.0     2070.0
# var       12.0      656.0
# det       13.0      834.0

# %%
# Vi kan legge på et varmekart for lettere å få oversikt

nb.heatmap(vestly.frame.head(20))
# Out:
# <style type="text/css">
# #T_42ac6_row0_col0, #T_42ac6_row0_col1, #T_42ac6_row0_col2, #T_42ac6_row0_col3, #T_42ac6_row0_col4, #T_42ac6_row0_col5, #T_42ac6_row0_col6, #T_42ac6_row0_col7, #T_42ac6_row0_col8, #T_42ac6_row0_col9, #T_42ac6_row0_col10, #T_42ac6_row0_col11, #T_42ac6_row0_col13, #T_42ac6_row0_col16, #T_42ac6_row0_col17, #T_42ac6_row2_col12, #T_42ac6_row2_col14, #T_42ac6_row2_col15, #T_42ac6_row2_col18, #T_42ac6_row2_col19 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_42ac6_row0_col12 {
#   background-color: #058205;
#   color: #f1f1f1;
# }
# #T_42ac6_row0_col14 {
#   background-color: #4ca54c;
#   color: #f1f1f1;
# }
# #T_42ac6_row0_col15 {
#   background-color: #289328;
#   color: #f1f1f1;
# }
# #T_42ac6_row0_col18 {
#   background-color: #1f8f1f;
#   color: #f1f1f1;
# }
# #T_42ac6_row0_col19 {
#   background-color: #048204;
#   color: #f1f1f1;
# }
# #T_42ac6_row1_col0 {
#   background-color: #2d962d;
#   color: #f1f1f1;
# }
# #T_42ac6_row1_
{
#   background-color: #86c286;
#   color: #000000;
# }
# #T_36a56_row2_col9 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_36a56_row2_col10 {
#   background-color: #88c388;
#   color: #000000;
# }
# #T_36a56_row2_col16 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_36a56_row2_col17 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_36a56_row2_col19 {
#   background-color: #90c790;
#   color: #000000;
# }
# #T_36a56_row3_col0, #T_36a56_row4_col0, #T_36a56_row5_col0 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_36a56_row3_col1 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_36a56_row3_col2 {
#   background-color: #badbba;
#   color: #000000;
# }
# #T_36a56_row3_col4 {
#   background-color: #d7e9d7;
#   color: #000000;
# }
# #T_36a56_row3_col5 {
#   background-color: #78bb78;
#   color: #f1f1f1;
# }
# #T_36a56_row3_col6, #T_36a56_row3_col10 {
#   background-color: #c3e0c3;
#   color: #000000;
# }
# #T_36a56_row3_col9 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_36a56_row3_col16, #T_36a56_row5_col17 {
#   background-color: #a5d1a5;
#   color: #000000;
# }
# #T_36a56_row3_col17 {
#   background-color: #c4e0c4;
#   color: #000000;
# }
# #T_36a56_row3_col19 {
#   background-color: #299429;
#   color: #f1f1f1;
# }
# #T_36a56_row4_col4 {
#   background-color: #89c389;
#   color: #000000;
# }
# #T_36a56_row5_col2 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_36a56_row5_col4 {
#   background-color: #138913;
#   color: #f1f1f1;
# }
# #T_36a56_row5_col6, #T_36a56_row5_col10 {
#   background-color: #a6d1a6;
#   color: #000000;
# }
# #T_36a56_row5_col7 {
#   background-color: #038103;
#   color: #f1f1f1;
# }
# #T_36a56_row5_col9 {
#   background-color: #c2dfc2;
#   color: #000000;
# }
# #T_36a56_row5_col12 {
#   background-color: #028102;
#   color: #f1f1f1;
# }
# #T_36a56_row6_col4 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# #T_36a56_row6_col8 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_36a56_row7_col4 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# </style>
# <table id="T_36a56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36a56_level0_col0" class="col_heading level0 col0" >100503685</th>
#       <th id="T_36a56_level0_col1" class="col_heading level0 col1" >100503477</th>
#       <th id="T_36a56_level0_col2" class="col_heading level0 col2" >100503478</th>
#       <th id="T_36a56_level0_col3" class="col_heading level0 col3" >100516696</th>
#       <th id="T_36a56_level0_col4" class="col_heading level0 col4" >100445919</th>
#       <th id="T_36a56_level0_col5" class="col_heading level0 col5" >100440922</th>
#       <th id="T_36a56_level0_col6" class="col_heading level0 col6" >100558943</th>
#       <th id="T_36a56_level0_col7" class="col_heading level0 col7" >100401171</th>
#       <th id="T_36a56_level0_col8" class="col_heading level0 col8" >100566074</th>
#       <th id="T_36a56_level0_col9" class="col_heading level0 col9" >100463823</th>
#       <th id="T_36a56_level0_col10" class="col_heading level0 col10" >100031786</th>
#       <th id="T_36a56_level0_col11" class="col_heading level0 col11" >100035823</th>
#       <th id="T_36a56_level0_col12" class="col_heading level0 col12" >100039821</th>
#       <th id="T_36a56_level0_col13" class="col_heading level0 col13" >100124378</th>
#       <th id="T_36a56_level0_col14" class="col_heading level0 col14" >100164506</th>
#       <th id="T_36a56_level0_col15" class="col_heading level0 col15" >100495412</th>
#       <th id="T_36a56_level0_col16" class="col_heading level0 col16" >100235984</th>
#       <th id="T_36a56_level0_col17" class="col_heading level0 col17" >100325187</th>
#       <th id="T_36a56_level0_col18" class="col_heading level0 col18" >100351724</th>
#       <th id="T_36a56_level0_col19" class="col_heading level0 col19" >100387104</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36a56_level0_row0" class="row_heading level0 row0" >Ole</th>
#       <td id="T_36a56_row0_col0" class="data row0 col0" >13.000000</td>
#       <td id="T_36a56_row0_col1" class="data row0 col1" >20.000000</td>
#       <td id="T_36a56_row0_col2" class="data row0 col2" >46.000000</td>
#       <td id="T_36a56_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_36a56_row0_col4" class="data row0 col4" >13.000000</td>
#       <td id="T_36a56_row0_col5" class="data row0 col5" >7.000000</td>
#       <td id="T_36a56_row0_col6" class="data row0 col6" >46.000000</td>
#       <td id="T_36a56_row0_col7" class="data row0 col7" >309.000000</td>
#       <td id="T_36a56_row0_col8" class="data row0 col8" >2.000000</td>
#       <td id="T_36a56_row0_col9" class="data row0 col9" >93.000000</td>
#       <td id="T_36a56_row0_col10" clas

# %%
# Er forfatteren konsekvent når det kommer til ordformer?

heatmap_loc(vestly.frame, "boken boka sola solen".split())
# Out:
# <style type="text/css">
# #T_95aff_row0_col0, #T_95aff_row0_col4, #T_95aff_row0_col5, #T_95aff_row0_col7, #T_95aff_row0_col8, #T_95aff_row0_col9, #T_95aff_row1_col2, #T_95aff_row1_col6, #T_95aff_row1_col10, #T_95aff_row1_col13, #T_95aff_row1_col16, #T_95aff_row1_col17, #T_95aff_row2_col15, #T_95aff_row3_col14, #T_95aff_row3_col19 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_95aff_row0_col1, #T_95aff_row0_col2, #T_95aff_row0_col3, #T_95aff_row0_col11, #T_95aff_row0_col12, #T_95aff_row0_col13, #T_95aff_row0_col14, #T_95aff_row0_col15, #T_95aff_row0_col16, #T_95aff_row0_col18, #T_95aff_row0_col19, #T_95aff_row1_col1, #T_95aff_row1_col3, #T_95aff_row1_col5, #T_95aff_row1_col7, #T_95aff_row1_col8, #T_95aff_row1_col9, #T_95aff_row1_col11, #T_95aff_row1_col12, #T_95aff_row1_col14, #T_95aff_row1_col18, #T_95aff_row1_col19, #T_95aff_row2_col0, #T_95aff_row2_col1, #T_95aff_row2_col2, #T_95aff_row2_col3, #T_95aff_row2_col5, #T_95aff_row2_col6, #T_95aff_row2_col7, #T_95aff_row2_col8, #T_95aff_row2_col9, #T_95aff_row2_col10, #T_95aff_row2_col11, #T_95aff_row2_col12, #T_95aff_row2_col13, #T_95aff_row2_col16, #T_95aff_row2_col17, #T_95aff_row2_col18, #T_95aff_row2_col19, #T_95aff_row3_col0, #T_95aff_row3_col1, #T_95aff_row3_col2, #T_95aff_row3_col3, #T_95aff_row3_col4, #T_95aff_row3_col5, #T_95aff_row3_col7, #T_95aff_row3_col8, #T_95aff_row3_col9, #T_95aff_row3_col11, #T_95aff_row3_col12, #T_95aff_row3_col13, #T_95aff_row3_col16, #T_95aff_row3_col18 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_95aff_row0_col6, #T_95aff_row0_col10, #T_95aff_row0_col17, #T_95aff_row3_col6, #T_95aff_row3_col10, #T_95aff_row3_col17 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_95aff_row1_col0 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_95aff_row1_col4 {
#   background-color: #cfe5cf;
#   color: #000000;
# }
# #T_95aff_row1_col15 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_95aff_row2_col4 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_95aff_row2_col14 {
#   background-color: #86c286;
#   color: #000000;
# }
# #T_95aff_row3_col15 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_95aff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95aff_level0_col0" class="col_heading level0 col0" >100503685</th>
#       <th id="T_95aff_level0_col1" class="col_heading level0 col1" >100503477</th>
#       <th id="T_95aff_level0_col2" class="col_heading level0 col2" >100503478</th>
#       <th id="T_95aff_level0_col3" class="col_heading level0 col3" >100516696</th>
#       <th id="T_95aff_level0_col4" class="col_heading level0 col4" >100445919</th>
#       <th id="T_95aff_level0_col5" class="col_heading level0 col5" >100440922</th>
#       <th id="T_95aff_level0_col6" class="col_heading level0 col6" >100558943</th>
#       <th id="T_95aff_level0_col7" class="col_heading level0 col7" >100401171</th>
#       <th id="T_95aff_level0_col8" class="col_heading level0 col8" >100566074</th>
#       <th id="T_95aff_level0_col9" class="col_heading level0 col9" >100463823</th>
#       <th id="T_95aff_level0_col10" class="col_heading level0 col10" >100031786</th>
#       <th id="T_95aff_level0_col11" class="col_heading level0 col11" >100035823</th>
#       <th id="T_95aff_level0_col12" class="col_heading level0 col12" >100039821</th>
#       <th id="T_95aff_level0_col13" class="col_heading level0 col13" >100124378</th>
#       <th id="T_95aff_level0_col14" class="col_heading level0 col14" >100164506</th>
#       <th id="T_95aff_level0_col15" class="col_heading level0 col15" >100495412</th>
#       <th id="T_95aff_level0_col16" class="col_heading level0 col16" >100235984</th>
#       <th id="T_95aff_level0_col17" class="col_heading level0 col17" >100325187</th>
#       <th id="T_95aff_level0_col18" class="col_heading level0 col18" >100351724</th>
#       <th id="T_95aff_level0_col19" class="col_heading level0 col19" >100387104</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95aff_level0_row0" class="row_heading level0 row0" >boken</th>
#       <td id="T_95aff_row0_col0" class="data row0 col0" >9.000000</td>
#       <td id="T_95aff_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_95aff_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_95aff_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_95aff_row0_col4" class="data row0 col4" >17.000000</td>
#       <td id="T_95aff_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_95aff_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_95aff_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_95aff_row0_col8" class="data row0 col8" >3.000000</td>
#       <td id="T_95aff_row0_col9" class="data row0 col9" >3.000000</td>
#       <td id="T_95aff_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_95aff_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_95aff_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_95aff_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_95aff_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_95aff_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_95aff_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_95aff_row0_col17" class="data row0 col17" >1.000000</td>
#       <td id="T_95aff_row0_col18" class="data row0 col18" >0.000000</td>
#       <td id="T_95aff_row0_col19" class="data row0 col19" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_95aff_level0_row1" class="row_heading level0 row1" >solen</th>
#       <td id="T_95aff_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_95aff_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_95aff_row1_col2" class="data row1 col2" >3.000000</td>
#       <td id="T_95aff_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_95aff_row1_col4" class="data row1 col4" >2.000000</td>
#       <td id="T_95aff_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_95aff_row1_col6" class="data row1 col6" >3.000000</td>
#       <td id="T_95aff_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_95aff_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_95aff_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_95aff_row1_col10" class="data row1 col10" >3.000000</td>
#       <td id="T_95aff_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_95aff_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_95aff_row1_col13" class="data row1 col13" >1.000000</td>
#       <td id="T_95aff_row1_col14" class="data row1 col14" >0.000000</td>
#       <td id="T_95aff_row1_col15" class="data row1 col15" >1.000000</td>
#       <td id="T_95aff_row1_col16" class="data row1 col16" >1.000000</td>
#       <td id="T_95aff_row1_col17" class="data row1 col17" >3.000000</td>
#       <td id="T_95aff_row1_col18" class="data row1 col18" >0.000000</td>
#       <td id="T_95aff_row1_col19" class="data row1 col19" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_95aff_level0_row2" class="row_heading level0 row2" >boka</th>
#       <td id="T_95aff_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_95aff_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_95aff_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_95aff_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_95aff_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_95aff_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_95aff_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_95aff_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_95aff_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_95aff_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_95aff_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_95aff_row2_col11" class="data row2 col11" >0.000000</td>
#       <td id="T_95aff_row2_col12" class="data row2 col12" >0.0
